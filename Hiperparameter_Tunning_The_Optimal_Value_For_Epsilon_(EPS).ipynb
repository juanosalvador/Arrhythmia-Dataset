# %% [markdown]
# <a href="https://colab.research.google.com/github/juanosalvador/Arrhythmia-Dataset/blob/master/Hiperparameter_Tunning_The_Optimal_Value_For_Epsilon_(EPS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#sklearn
#from sklearn import cluster, datasets, mixture
from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons

# %% [markdown]
# Hi there! In this entries we calculate the optimal value for epsilon using a heuristic method. The method that we use is KNN in order to select the avegare distance of a k neigbohrs. We try with difference value for K.

# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
## Load synthetic date
# blobs with varied variances
n_samples = 2500
n_features = 2
n_clusters = 4
random_state = 42
#max_iter = 100

X, y = make_blobs(n_samples=n_samples, 
                  n_features=n_features, 
                  cluster_std=1.3,
                  centers=n_clusters, 
                  random_state=random_state)
plt.scatter(X[:,0],X[:,1], s = 20)
plt.show()

# %%
## make moon
Xm, ym = make_moons(2500, noise=.1, random_state=0)
plt.scatter(Xm[:,0], Xm[:,1])

# %%
## Concatenate numpy arrays
X = np.concatenate((X,Xm),axis = 0)
plt.scatter(X[:,0], X[:,1], s = 10)
